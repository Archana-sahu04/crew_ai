# %%
'''
create a requirment.txt
    crewai
    duckduckgo-search
    huggingface_hub
    langchain_google_genai
'''

# %%
# !pip install -r requirement.txt

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from crewai import Agent, Task, Crew, Process
from langchain_community.tools import DuckDuckGoSearchRun

# %%
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash",
                             verbose = True,
                             temperature = 0.5,
                             google_api_key="your api

# %%
google_model = "gemini-1.5-flash-8b-exp-0827"

# %%
# pip install crewai-tools
# !pip install -U crewai crewai-tools google-search-results

# %%
#create searches
from crewai_tools import SerperDevTool

search_tool = SerperDevTool()

# %%
import os
os.environ["OPENAI_API_KEY"] = "your api"
os.environ["GOOGLE_API_KEY"]="your api"

# %%
# Define Agents
email_author = Agent(
    role='Professional Email Author',
    goal='Craft concise and engaging emails',
    backstory='Experienced in writing impactful marketing emails.',
    verbose=True,
    allow_delegation=False,
    llm="gpt-4",
    tools=[search_tool],
)
marketing_strategist = Agent(
    role='Marketing Strategist',
    goal='Lead the team in creating effective cold emails',
    backstory='A seasoned Chief Marketing Officer with a keen eye for standout marketing content.',
    verbose=True,
    allow_delegation=True,
    llm="gpt-4"
)

content_specialist = Agent(
    role='Content Specialist',
    goal='Critique and refine email content',
    backstory='A professional copywriter with a wealth of experience in persuasive writing.',
    verbose=True,
    allow_delegation=False,
    llm="gpt-4"
)

# Define Task
email_task = Task(
    description='''1. Generate two distinct variations of a cold email promoting a video editing solution.
    2. Evaluate the written emails for their effectiveness and engagement.
    3. Scrutinize the emails for grammatical correctness and clarity.
    4. Adjust the emails to align with best practices for cold outreach. Consider the feedback
    provided to the marketing_strategist.
    5. Revise the emails based on all feedback, creating two final versions.''',
    agent=marketing_strategist,  # The Marketing Strategist is in charge and can delegate
    expected_output=""
    )


# Create a Single Crew
email_crew = Crew(
    agents=[email_author, marketing_strategist, content_specialist],
    tasks=[email_task],
    verbose=True,
    process=Process.sequential
)

# Execution Flow
print("Crew: Working on Email Task")
emails_output = email_crew.kickoff()
# Out:
# Crew: Working on Email Task
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 3193549a-5827-4e04-afc9-63d23c2c765d                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: 1. Generate two distinct variations of a cold email promoting a video editing solution.                  │
# │      2. Evaluate the written emails for their effectiveness and engagement.                                     │
# │      3. Scrutinize the emails for grammatical correctness and clarity.                                          │
# │      4. Adjust the emails to align with best practices for cold outreach. Consider the feedback                 │
# │      provided to the marketing_strategist.                                                                      │
# │      5. Revise the emails based on all feedback, creating two final versions.                                   │
# │  ID: f3e9d4f3-d35b-484d-885d-1cc40b698d7a                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Marketing Strategist                                                                                    │
# │                                                                                                                 │
# │  Task: 1. Generate two distinct variations of a cold email promoting a video editing solution.                  │
# │      2. Evaluate the written emails for their effectiveness and engagement.                                     │
# │      3. Scrutinize the emails for grammatical correctness and clarity.                                          │
# │      4. Adjust the emails to align with best practices for cold outreach. Consider the feedback                 │
# │      provided to the marketing_strategist.                                                                      │
# │      5. Revise the emails based on all feedback, creating two final versions.                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# ERROR:root:OpenAI API call failed: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or     │
# │  you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'llm_call_failed' closed 'agent_execution_started' (expected
# 'llm_call_started')
# An unknown error occurred. Please check the details below.
# Error details: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# An unknown error occurred. Please check the details below.
# Error details: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: OpenAI API call failed: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model       │
# │  `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None,      │
# │  'code': 'model_not_found'}}                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Marketing Strategist                                                                                    │
# │                                                                                                                 │
# │  Task: 1. Generate two distinct variations of a cold email promoting a video editing solution.                  │
# │      2. Evaluate the written emails for their effectiveness and engagement.                                     │
# │      3. Scrutinize the emails for grammatical correctness and clarity.                                          │
# │      4. Adjust the emails to align with best practices for cold outreach. Consider the feedback                 │
# │      provided to the marketing_strategist.                                                                      │
# │      5. Revise the emails based on all feedback, creating two final versions.                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# ERROR:root:OpenAI API call failed: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or     │
# │  you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'llm_call_failed' closed 'agent_execution_started' (expected
# 'llm_call_started')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# An unknown error occurred. Please check the details below.
# Error details: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: OpenAI API call failed: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model       │
# │  `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None,      │
# │  'code': 'model_not_found'}}                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Marketing Strategist                                                                                    │
# │                                                                                                                 │
# │  Task: 1. Generate two distinct variations of a cold email promoting a video editing solution.                  │
# │      2. Evaluate the written emails for their effectiveness and engagement.                                     │
# │      3. Scrutinize the emails for grammatical correctness and clarity.                                          │
# │      4. Adjust the emails to align with best practices for cold outreach. Consider the feedback                 │
# │      provided to the marketing_strategist.                                                                      │
# │      5. Revise the emails based on all feedback, creating two final versions.                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# ERROR:root:OpenAI API call failed: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or     │
# │  you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'llm_call_failed' closed 'agent_execution_started' (expected
# 'llm_call_started')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# An unknown error occurred. Please check the details below.
# Error details: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'agent_execution_error' closed 'task_started' (expected
# 'agent_execution_started')
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: OpenAI API call failed: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model       │
# │  `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None,      │
# │  'code': 'model_not_found'}}                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'task_failed' closed 'crew_kickoff_started' (expected
# 'task_started')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Failure ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: 1. Generate two distinct variations of a cold email promoting a video editing solution.                  │
# │      2. Evaluate the written emails for their effectiveness and engagement.                                     │
# │      3. Scrutinize the emails for grammatical correctness and clarity.                                          │
# │      4. Adjust the emails to align with best practices for cold outreach. Consider the feedback                 │
# │      provided to the marketing_strategist.                                                                      │
# │      5. Revise the emails based on all feedback, creating two final versions.                                   │
# │  Agent: Marketing Strategist                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [CrewAIEventsBus] Warning: Ending event 'crew_kickoff_failed' emitted with empty scope stack. Missing starting
# event?
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: 3193549a-5827-4e04-afc9-63d23c2c765d                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/openai/completion.py in _handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#    1620
# -> 1621             response: ChatCompletion = self.client.chat.completions.create(**params)
#    1622
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     285                 raise TypeError(msg)
# --> 286             return func(*args, **kwargs)
#     287
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/chat/completions/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1210         validate_response_format(response_format)
# -> 1211         return self._post(
#    1212             "/chat/completions",
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1296         )
# -> 1297         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1298
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1069                 log.debug("Re-raising status error")
# -> 1070                 raise self._make_status_error_from_response(err.response) from None
#    1071
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_498/952862047.py in <cell line: 0>()
#      50 # Execution Flow
#      51 print("Crew: Working on Email Task")
# ---> 52 emails_output = email_crew.kickoff()
#
# /usr/local/lib/python3.12/dist-packages/crewai/crew.py in kickoff(self, inputs, input_files)
#     737
#     738             if self.process == Process.sequential:
# --> 739                 result = self._run_sequential_process()
#     740             elif self.process == Process.hierarchical:
#     741                 result = self._run_hierarchical_process()
#
# /usr/local/lib/python3.12/dist-packages/crewai/crew.py in _run_sequential_process(self)
#    1162     def _run_sequential_process(self) -> CrewOutput:
#    1163         """Executes tasks sequentially and returns the final output."""
# -> 1164         return self._execute_tasks(self.tasks)
#    1165
#    1166     def _run_hierarchical_process(self) -> CrewOutput:
#
# /usr/local/lib/python3.12/dist-packages/crewai/crew.py in _execute_tasks(self, tasks, start_index, was_replayed)
#    1254
#    1255                 context = self._get_context(task, task_outputs)
# -> 1256                 task_output = task.execute_sync(
#    1257                     agent=exec_data.agent,
#    1258                     context=context,
#
# /usr/local/lib/python3.12/dist-packages/crewai/task.py in execute_sync(self, agent, context, tools)
#     503         """Execute the task synchronously."""
#     504         self.start_time = datetime.datetime.now()
# --> 505         return self._execute_core(agent, context, tools)
#     506
#     507     @property
#
# /usr/local/lib/python3.12/dist-packages/crewai/task.py in _execute_core(self, agent, context, tools)
#     784             self.end_time = datetime.datetime.now()
#     785             crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 786             raise e  # Re-raise the exception after emitting the event
#     787         finally:
#     788             clear_task_files(self.id)
#
# /usr/local/lib/python3.12/dist-packages/crewai/task.py in _execute_core(self, agent, context, tools)
#     696             self.processed_by_agents.add(agent.role)
#     697             crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))
# --> 698             result = agent.execute_task(
#     699                 task=self,
#     700                 context=context,
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in execute_task(self, task, context, tools)
#     727             raise e
#     728         except Exception as e:
# --> 729             result = self._handle_execution_error(e, task, context, tools)
#     730
#     731         return self._finalize_task_execution(task, result)
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in _handle_execution_error(self, e, task, context, tools)
#     639         """
#     640         self._check_execution_error(e, task)
# --> 641         return self.execute_task(task, context, tools)
#     642
#     643     async def _handle_execution_error_async(
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in execute_task(self, task, context, tools)
#     727             raise e
#     728         except Exception as e:
# --> 729             result = self._handle_execution_error(e, task, context, tools)
#     730
#     731         return self._finalize_task_execution(task, result)
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in _handle_execution_error(self, e, task, context, tools)
#     639         """
#     640         self._check_execution_error(e, task)
# --> 641         return self.execute_task(task, context, tools)
#     642
#     643     async def _handle_execution_error_async(
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in execute_task(self, task, context, tools)
#     727             raise e
#     728         except Exception as e:
# --> 729             result = self._handle_execution_error(e, task, context, tools)
#     730
#     731         return self._finalize_task_execution(task, result)
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in _handle_execution_error(self, e, task, context, tools)
#     638             Result from retried execution.
#     639         """
# --> 640         self._check_execution_error(e, task)
#     641         return self.execute_task(task, context, tools)
#     642
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in _check_execution_error(self, e, task)
#     618                 ),
#     619             )
# --> 620             raise e
#     621
#     622     def _handle_execution_error(
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in execute_task(self, task, context, tools)
#     714                 )
#     715             else:
# --> 716                 result = self._execute_without_timeout(task_prompt, task)
#     717
#     718         except TimeoutError as e:
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in _execute_without_timeout(self, task_prompt, task)
#     779             raise RuntimeError("Agent executor is not initialized.")
#     780
# --> 781         return self.agent_executor.invoke(
#     782             {
#     783                 "input": task_prompt,
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/crew_agent_executor.py in invoke(self, inputs)
#     225
#     226         try:
# --> 227             formatted_answer = self._invoke_loop()
#     228         except AssertionError:
#     229             if self.agent.verbose:
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/crew_agent_executor.py in _invoke_loop(self)
#     321
#     322         if use_native_tools:
# --> 323             return self._invoke_loop_native_tools()
#     324
#     325         # Fall back to ReAct text-based pattern
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/crew_agent_executor.py in _invoke_loop_native_tools(self)
#     595                     continue
#     596                 handle_unknown_error(self._printer, e, verbose=self.agent.verbose)
# --> 597                 raise e
#     598             finally:
#     599                 self.iterations += 1
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/crew_agent_executor.py in _invoke_loop_native_tools(self)
#     514                 # without executing them. The executor handles tool execution
#     515                 # via _handle_native_tool_calls to properly manage message history.
# --> 516                 answer = get_llm_response(
#     517                     llm=self.llm,
#     518                     messages=self.messages,
#
# /usr/local/lib/python3.12/dist-packages/crewai/utilities/agent_utils.py in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     473         )
#     474     except Exception as e:
# --> 475         raise e
#     476
#     477     return _validate_and_finalize_llm_response(
#
# /usr/local/lib/python3.12/dist-packages/crewai/utilities/agent_utils.py in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     463
#     464     try:
# --> 465         answer = llm.call(
#     466             messages,
#     467             tools=tools,
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/openai/completion.py in call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     440                     )
#     441
# --> 442                 return self._call_completions(
#     443                     messages=formatted_messages,
#     444                     tools=tools,
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/openai/completion.py in _call_completions(self, messages, tools, available_functions, from_task, from_agent, response_model)
#     480             )
#     481
# --> 482         return self._handle_completion(
#     483             params=completion_params,
#     484             available_functions=available_functions,
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/openai/completion.py in _handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#    1702                 error=error_msg, from_task=from_task, from_agent=from_agent
#    1703             )
# -> 1704             raise ValueError(error_msg) from e
#    1705         except APIConnectionError as e:
#    1706             error_msg = f"Failed to connect to OpenAI API: {e}"
#
# ValueError: Model gpt-4 not found: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────────── Execution Traces ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  🔍 Detailed execution traces are available!                                                                    │
# │                                                                                                                 │
# │  View insights including:                                                                                       │
# │    • Agent decision-making process                                                                              │
# │    • Task execution flow and timing                                                                             │
# │    • Tool usage details                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):
